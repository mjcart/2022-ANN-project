# %% [markdown]
# # setup

# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
print("sklearn version: ", sklearn.__version__)
assert sklearn.__version__ >= "0.20"

try:
    # %tensorflow_version only exists in Colab.
    # %tensorflow_version 2.x
    IS_COLAB = True
except Exception:
    IS_COLAB = False

# TensorFlow ≥2.0 is required
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow import keras
print("TF version: ", tf.__version__)
assert tf.__version__ >= "2.0"

if not tf.config.list_physical_devices('GPU'):
    print("No GPU was detected. CNNs can be very slow without a GPU.")
    if IS_COLAB:
        print("Go to Runtime > Change runtime and select a GPU hardware accelerator.")

# GPU test
print("GPU installed: ",tf.test.is_built_with_gpu_support())

# To prevent "CUDNN_STATUS_ALLOC_FAILED" error with GPUs
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
    
# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
np.random.seed(42)
tf.random.set_seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "cnn"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)
    
# Ignore useless warnings (see SciPy issue #5998)
import warnings
warnings.filterwarnings(action="ignore", message="^internal gelsd")    

from tensorflow.python.keras.utils.data_utils import Sequence
# Out:
# sklearn version:  0.24.2
# TF version:  2.8.0
# GPU installed:  True
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# # Get the data

# %%
#작성자 전민재
import csv
def load_Emist(exsitNumpy=False, needTranspose=True):
    if (exsitNumpy == False):
        #"./emnist-byclass-test.csv"
        #train-set
        #"공용/datasets/Emnist/" 위치에 csv 저장 
        csv_train_data_file = open("../공용/datasets/Emnist/train_data.csv", "r", encoding="ms932", errors="", newline="" ) #리스트 형식 
        csv_train_label_file = open("../공용/datasets/Emnist/train_label.csv", "r", encoding="ms932", errors="", newline="" ) #리스트 형식 
    
        
        f_train = csv.reader(csv_train_data_file, delimiter=",", doublequote=True, lineterminator="\r\n", quotechar='"', skipinitialspace=True)
        l_train=csv.reader(csv_train_label_file, delimiter=",", doublequote=True, lineterminator="\r\n", quotechar='"', skipinitialspace=True)
        #valid-set
    
        csv_valid_data_file = open("../공용/datasets/Emnist/valid_data.csv", "r", encoding="ms932", errors="", newline="" ) #리스트 형식 
        csv_valid_label_file = open("../공용/datasets/Emnist/valid_label.csv", "r", encoding="ms932", errors="", newline="" ) #리스트 형식 
        
        f_valid = csv.reader(csv_valid_data_file, delimiter=",", doublequote=True, lineterminator="\r\n", quotechar='"', skipinitialspace=True)
        l_valid = csv.reader(csv_valid_label_file, delimiter=",", doublequote=True, lineterminator="\r\n", quotechar='"', skipinitialspace=True)
        X_train=[]
        y_train=[]
        X_valid=[]
        y_valid=[]
        for i, row in enumerate(f_train):
            #행마다 int로 형변환
            for idx, char in enumerate(row):
                row[idx]=int(char)
            #train
            #data 추가    
            X_train.append(row)
            
        for i, row in enumerate(f_valid):
            #행마다 int로 형변환
            for idx, char in enumerate(row):
                row[idx]=int(char)
            #valid
            #data 추가    
            X_valid.append(row)


        for i, row in enumerate(l_train):

            #train
            #label 추가
            y_train.append(int(row[0]))
            
        for i, row in enumerate(l_valid):

            #valid
            #label 추가
            y_valid.append(int(row[0]))
            
            
        

        #train
        X_train=np.array(X_train,dtype=np.uint8)
        X_train=X_train.reshape(-1,28,28)
        #valid
        X_valid=np.array(X_valid,dtype=np.uint8)
        X_valid=X_valid.reshape(-1,28,28)
        
        csv_train_data_file.close()
        csv_train_label_file.close()
        csv_valid_data_file.close()
        csv_valid_label_file.close()
        
        #kaggle dataset이 시계반대방향으로 90도 회전 되있고 상하 반전 되어있음
        def rotate_90(m):
            N = len(m)
            ret = [[0] * N for _ in range(N)]

            for r in range(N):
                for c in range(N):
                    ret[c][N-1-r] = m[r][c]
            return np.array(ret,dtype=np.uint8)

        def vreflect(m):
            N = len(m)
            ret = [[0] * N for _ in range(N)]

            for r in range(N):
                for c in range(N):
                    ret[r][c] = m[r][N-1-c]
            return np.array(ret,dtype=np.uint8)
        
        if needTranspose == True:
            #train
            #회전
            for idx,i in enumerate(X_train):
                X_train[idx]=rotate_90(i)
            #상하반전
            for idx,i in enumerate(X_train):
                X_train[idx]=vreflect(i)

            #valid
            #회전
            for idx,i in enumerate(X_valid):
                X_valid[idx]=rotate_90(i)
            #상하반전
            for idx,i in enumerate(X_valid):
                X_valid[idx]=vreflect(i)

       
        
        
        #저장용
        #train
        #(533917,28,28)
        np.save('../공용/X_train',X_train)
        np.save('../공용/y_train',y_train)
        #valid
        np.save('../공용/X_valid',X_valid)
        np.save('../공용/y_valid',y_valid)
        
   
    X_train=np.load('../공용/X_train.npy')
    y_train=np.load('../공용/y_train.npy')
    X_valid=np.load('../공용/X_valid.npy')
    y_valid=np.load('../공용/y_valid.npy')
    
    return X_train, y_train, X_valid, y_valid

# %%
#황성현
#npy 파일이 존재할 경우 exsitNumpy = True, 업으면 False
X_train, y_train, X_valid, y_valid = load_Emist(exsitNumpy=True)
X_train.shape,X_train.dtype
# Out:
# ((533917, 28, 28), dtype('uint8'))

# %%
X_train_letters = X_train[np.where(y_train>10)]

# %%
y_train_letters = y_train[np.where(y_train>10)]

# %%
for i in range (3):
    X_train = np.append(X_train,X_train_letters,axis=0)
    y_train = np.append(y_train, y_train_letters,axis=0)

# %%
X_train.shape
# Out:
# (1329679, 28, 28)

# %%
import gc
del X_train_letters, y_train_letters
gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
#이승훈
import cv2 as cv
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
ids=1
X_new=X_train[ids]
y_new=y_train[ids]
c=X_new.reshape(28,28)


plt.imshow(c, cmap="binary")
plt.axis('off')
plt.show()
print(y_new)
# Out:
# 28

# %% [markdown]
# # Prepare the data

# %%
#황성현
#data, batch size 성정
train_size=len(X_train)
valid_size=len(X_valid)
batch_size=32
train_size
# Out:
# 1329679

# %%
#황성현
X_train=np.reshape(X_train,[-1,784])
X_valid=np.reshape(X_valid,[-1,784])
X_train.shape,X_valid.shape
# Out:
# ((1329679, 784), (164015, 784))

# %%
#황성현
y_train=np.reshape(y_train,[-1,1])
y_valid=np.reshape(y_valid,[-1,1])

y_train.shape,y_valid.shape
# Out:
# ((1329679, 1), (164015, 1))

# %%
n_inputs = X_train.shape[-1]
print("n_inputs =",n_inputs)
# Out:
# n_inputs = 784

# %%
#황성현
def save_to_multiple_csv_files(data, name_prefix, header=None, n_parts=10):
    
    Emnist_dir = os.path.join("../공용/datasets", "Emnist")
    os.makedirs(Emnist_dir, exist_ok=True)
    path_format = os.path.join(Emnist_dir, "my_{}_{:02d}.csv")

    filepaths = []
    m = len(data)
    for file_idx, row_indices in enumerate(np.array_split(np.arange(m), n_parts)):
        part_csv = path_format.format(name_prefix, file_idx)
        filepaths.append(part_csv)
        try:
            with open(part_csv, "xt", encoding="utf-8") as f:
                if header is not None:
                    f.write(header)
                    f.write("\n")
                for row_idx in row_indices:
                    f.write(",".join([repr(col) for col in data[row_idx]]))
                    f.write("\n")
        except:
            continue
    return filepaths

# %%
train_full=np.append(X_train,y_train,axis=1)

# %%
train_full.shape
# Out:
# (1329679, 785)

# %%
#황성현
#메모리 해제
del X_train, y_train
gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
#황성현
train_filepaths = save_to_multiple_csv_files(train_full, "train", n_parts=20)

# %%
valid_full=np.append(X_valid,y_valid,axis=1)

# %%
#황성현
#메모리 해제
del X_valid, y_valid
gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
#황성현

valid_filepaths = save_to_multiple_csv_files(valid_full, "valid", n_parts=20)

# %%
#황성현
#메모리 해제
del valid_full, train_full
gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
#황성현
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import random

def dataaugmentation(X):
    datagen=ImageDataGenerator(rotation_range=40,width_shift_range = 0.2, 
        height_shift_range = 0.2)
    #영어 부분 2배 생성
    #차원변환 
    X=tf.reshape(X,[28,28,1])

    #새로운 데이터 생성
    angle=(random.random()%1)*0.8 - 0.4
    image_result =tfa.image.rotate(X, tf.constant(angle))#rotate -pi/10 ~ pi/10
    shift=(random.random()%1)*2 - 1
    image_result=tfa.image.translate(image_result,[tf.constant(shift),tf.constant(shift)])
    
    return image_result

# %%
#황성현
@tf.function
def preprocess_mobilenet_v2(line,randomize=False):
    defs = [0.] * n_inputs + [tf.constant([], dtype=tf.float32)]
    fields = tf.io.decode_csv(line, record_defaults=defs)
    x = tf.stack(fields[:-1])
    x=tf.reshape(x,[28,28,1])
    y = tf.stack(fields[-1:])
    augment_image = x
    if y > 10 and randomize:
        augment_image = dataaugmentation(x)
        
        
    resized_image = tf.image.resize(augment_image, [224, 224])
    if resized_image.shape[2] == 1:
        temp=tf.concat([resized_image,resized_image],2)
        resized_image=tf.concat([temp,resized_image],2)
    final_image = keras.applications.mobilenet_v2.preprocess_input(resized_image)
    
    return final_image, y

@tf.function
def preprocess_resnet50(line,randomize=False):
    defs = [0.] * n_inputs + [tf.constant([], dtype=tf.float32)]
    fields = tf.io.decode_csv(line, record_defaults=defs)
    x = tf.stack(fields[:-1])
    x=tf.reshape(x,[28,28,1])
    y = tf.stack(fields[-1:])
    augment_image = x
    if y > 10 and randomize:
        augment_image = dataaugmentation(x)
        
        
    resized_image = tf.image.resize(augment_image, [224, 224])
    if resized_image.shape[2] == 1:
        temp=tf.concat([resized_image,resized_image],2)
        resized_image=tf.concat([temp,resized_image],2)
    final_image = keras.applications.resnet50.preprocess_input(resized_image)
    
    return final_image, y

@tf.function
def preprocess_vgg16(line,randomize=False):
    defs = [0.] * n_inputs + [tf.constant([], dtype=tf.float32)]
    fields = tf.io.decode_csv(line, record_defaults=defs)
    x = tf.stack(fields[:-1])
    x=tf.reshape(x,[28,28,1])
    y = tf.stack(fields[-1:])
    augment_image = x
    if y > 10 and randomize:
        augment_image = dataaugmentation(x)
        
        
    resized_image = tf.image.resize(augment_image, [224, 224])
    if resized_image.shape[2] == 1:
        temp=tf.concat([resized_image,resized_image],2)
        resized_image=tf.concat([temp,resized_image],2)
    final_image = keras.applications.vgg16.preprocess_input(resized_image)
    
    return final_image, y

@tf.function
def preprocess_renet(line,randomize=False):
    defs = [0.] * n_inputs + [tf.constant([], dtype=tf.float32)]
    fields = tf.io.decode_csv(line, record_defaults=defs)
    x = tf.stack(fields[:-1])
    x=tf.reshape(x,[28,28,1])
    y = tf.stack(fields[-1:])
    augment_image = x
    if y > 10 and randomize:
        augment_image = dataaugmentation(x)
        
   
    return augment_image, y

@tf.function
def preprocess_xception(line,randomize=False):
    defs = [0.] * n_inputs + [tf.constant([], dtype=tf.float32)]
    fields = tf.io.decode_csv(line, record_defaults=defs)
    x = tf.stack(fields[:-1])
    x=tf.reshape(x,[28,28,1])
    y = tf.stack(fields[-1:])
    augment_image = x
    if y > 10 and randomize:
        augment_image = dataaugmentation(x)
        
        
    resized_image = tf.image.resize(augment_image, [224, 224])
    if resized_image.shape[2] == 1:
        temp=tf.concat([resized_image,resized_image],2)
        resized_image=tf.concat([temp,resized_image],2)
    final_image = keras.applications.xception.preprocess_input(resized_image)
    
    return final_image, y

@tf.function
def preprocess_inception_v3(line,randomize=False):
    defs = [0.] * n_inputs + [tf.constant([], dtype=tf.float32)]
    fields = tf.io.decode_csv(line, record_defaults=defs)
    x = tf.stack(fields[:-1])
    x=tf.reshape(x,[28,28,1])
    y = tf.stack(fields[-1:])
    augment_image = x
    if y > 10 and randomize:
        augment_image = dataaugmentation(x)
        
        
    resized_image = tf.image.resize(augment_image, [224, 224])
    if resized_image.shape[2] == 1:
        temp=tf.concat([resized_image,resized_image],2)
        resized_image=tf.concat([temp,resized_image],2)
    final_image = keras.applications.inception_v3.preprocess_input(resized_image)
    
    return final_image, y

# %%
#황성현
from enum import Enum
class eModelName(Enum):
    mobilenet_v2 = 0,
    resnet50 = 1,
    vgg16 = 3,
    renet = 4,
    xception = 5,
    inception_v3 = 6

# %%
#황성현
from functools import partial
def csv_reader_dataset(filepaths, model_name, repeat=1, n_readers=5,
                       n_read_threads=None, shuffle_buffer_size=10000,
                       n_parse_threads=5, batch_size=32,randomize=True):
    dataset = tf.data.Dataset.list_files(filepaths).repeat(repeat)
    dataset = dataset.interleave(
        lambda filepath: tf.data.TextLineDataset(filepath).skip(1),
        cycle_length=n_readers, num_parallel_calls=n_read_threads)
    dataset = dataset.shuffle(shuffle_buffer_size)
    if model_name == eModelName.mobilenet_v2:
        dataset = dataset.map(partial(preprocess_mobilenet_v2,randomize=randomize), num_parallel_calls=n_parse_threads)
        print(model_name.name)
    elif model_name == eModelName.resnet50:
        dataset = dataset.map(partial(preprocess_resnet50,randomize=randomize), num_parallel_calls=n_parse_threads)
        print(model_name.name)
    elif model_name == eModelName.vgg16:
        dataset = dataset.map(partial(preprocess_vgg16,randomize=randomize), num_parallel_calls=n_parse_threads)
        print(model_name.name)
    elif model_name == eModelName.renet:
        dataset = dataset.map(partial(preprocess_renet,randomize=randomize), num_parallel_calls=n_parse_threads)
        print(model_name.name)
    elif model_name == eModelName.xception:
        dataset = dataset.map(partial(preprocess_xception,randomize=randomize), num_parallel_calls=n_parse_threads)
        print(model_name.name)
    elif model_name == eModelName.inception_v3:
        dataset = dataset.map(partial(preprocess_inception_v3,randomize=randomize), num_parallel_calls=n_parse_threads)
        print(model_name.name)
    dataset = dataset.batch(batch_size)
    return dataset.prefetch(1)

# %%
#황성현
#csv_reader_dataset의 파라미터 model_name에 eModelNAme class의 맴버 변수 중 사용할 모델 입력
#ex) model_name = eModelName.inception_v3, model_name = eModelName.renet 
tf.random.set_seed(42)

train_set = csv_reader_dataset(train_filepaths, model_name = eModelName.inception_v3, batch_size=batch_size, repeat=None)
valid_set = csv_reader_dataset(valid_filepaths, model_name = eModelName.inception_v3, 
                               batch_size=batch_size, repeat=None, randomize = False)
train_set,valid_set
# Out:
# inception_v3
# inception_v3
# (<PrefetchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1), dtype=tf.float32, name=None))>,
#  <PrefetchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1), dtype=tf.float32, name=None))>)

# %% [markdown]
# # Inception-v3 by 박민성, 황성현

# %%
n_classes=62
base_model=tf.keras.applications.inception_v3.InceptionV3(weights='imagenet', include_top=False)
avg=tf.keras.layers.GlobalAveragePooling2D()(base_model.output)
output=keras.layers.Dense(n_classes, activation='softmax')(avg)
model_inceptionv3=keras.models.Model(inputs=base_model.input, outputs=output)

# %%
model_inceptionv3.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  conv2d_658 (Conv2D)            (None, None, None,   864         ['input_8[0][0]']
#                                 32)
#
#  batch_normalization_658 (Batch  (None, None, None,   96         ['conv2d_658[0][0]']
#  Normalization)                 32)
#
#  activation_658 (Activation)    (None, None, None,   0           ['batch_normalization_658[0][0]']
#                                 32)
#
#  conv2d_659 (Conv2D)            (None, None, None,   9216        ['activation_658[0][0]']
#                                 32)
#
#  batch_normalization_659 (Batch  (None, None, None,   96         ['conv2d_659[0][0]']
#  Normalization)                 32)
#
#  activation_659 (Activation)    (None, None, None,   0           ['batch_normalization_659[0][0]']
#                                 32)
#
#  conv2d_660 (Conv2D)            (None, None, None,   18432       ['activation_659[0][0]']
#                                 64)
#
#  batch_normalization_660 (Batch  (None, None, None,   192        ['conv2d_660[0][0]']
#  Normalization)                 64)
#
#  activation_660 (Activation)    (None, None, None,   0           ['batch_normalization_660[0][0]']
#                                 64)
#
#  max_pooling2d_28 (MaxPooling2D  (None, None, None,   0          ['activation_660[0][0]']
#  )                              64)
#
#  conv2d_661 (Conv2D)            (None, None, None,   5120        ['max_pooling2d_28[0][0]']
#                                 80)
#
#  batch_normalization_661 (Batch  (None, None, None,   240        ['conv2d_661[0][0]']
#  Normalization)                 80)
#
#  activation_661 (Activation)    (None, None, None,   0           ['batch_normalization_661[0][0]']
#                                 80)
#
#  conv2d_662 (Conv2D)            (None, None, None,   138240      ['activation_661[0][0]']
#                                 192)
#
#  batch_normalization_662 (Batch  (None, None, None,   576        ['conv2d_662[0][0]']
#  Normalization)                 192)
#
#  activation_662 (Activation)    (None, None, None,   0           ['batch_normalization_662[0][0]']
#                                 192)
#
#  max_pooling2d_29 (MaxPooling2D  (None, None, None,   0          ['activation_662[0][0]']
#  )                              192)
#
#  conv2d_666 (Conv2D)            (None, None, None,   12288       ['max_pooling2d_29[0][0]']
#                                 64)
#
#  batch_normalization_666 (Batch  (None, None, None,   192        ['conv2d_666[0][0]']
#  Normalization)                 64)
#
#  activation_666 (Activation)    (None, None, None,   0           ['batch_normalization_666[0][0]']
#                                 64)
#
#  conv2d_664 (Conv2D)            (None, None, None,   9216        ['max_pooling2d_29[0][0]']
#                                 48)
#
#  conv2d_667 (Conv2D)            (None, None, None,   55296       ['activation_666[0][0]']
#                                 96)
#
#  batch_normalization_664 (Batch  (None, None, None,   144        ['conv2d_664[0][0]']
#  Normalization)                 48)
#
#  batch_normalization_667 (Batch  (None, None, None,   288        ['conv2d_667[0][0]']
#  Normalization)                 96)
#
#  activation_664 (Activation)    (None, None, None,   0           ['batch_normalization_664[0][0]']
#                                 48)
#
#  activation_667 (Activation)    (None, None, None,   0           ['batch_normalization_667[0][0]']
#                                 96)
#
#  average_pooling2d_67 (AverageP  (None, None, None,   0          ['max_pooling2d_29[0][0]']
#  ooling2D)                      192)
#
#  conv2d_663 (Conv2D)            (None, None, None,   12288       ['max_pooling2d_29[0][0]']
#                                 64)
#
#  conv2d_665 (Conv2D)            (None, None, None,   76800       ['activation_664[0][0]']
#                                 64)
#
#  conv2d_668 (Conv2D)            (None, None, None,   82944       ['activation_667[0][0]']
#                                 96)
#
#  conv2d_669 (Conv2D)            (None, None, None,   6144        ['average_pooling2d_67[0][0]']
#                                 32)
#
#  batch_normalization_663 (Batch  (None, None, None,   192        ['conv2d_663[0][0]']
#  Normalization)                 64)
#
#  batch_normalization_665 (Batch  (None, None, None,   192        ['conv2d_665[0][0]']
#  Normalization)                 64)
#
#  batch_normalization_668 (Batch  (None, None, None,   288        ['conv2d_668[0][0]']
#  Normalization)                 96)
#
#  batch_normalization_669 (Batch  (None, None, None,   96         ['conv2d_669[0][0]']
#  Normalization)                 32)
#
#  activation_663 (Activation)    (None, None, None,   0           ['batch_normalization_663[0][0]']
#                                 64)
#
#  activation_665 (Activation)    (None, None, None,   0           ['batch_normalization_665[0][0]']
#                                 64)
#
#  activation_668 (Activation)    (None, None, None,   0           ['batch_normalization_668[0][0]']
#                                 96)
#
#  activation_669 (Activation)    (None, None, None,   0           ['batch_normalization_669[0][0]']
#                                 32)
#
#  mixed0 (Concatenate)           (None, None, None,   0           ['activation_663[0][0]',
#                                 256)                              'activation_665[0][0]',
#                                                                   'activation_668[0][0]',
#                                                                   'activation_669[0][0]']
#
#  conv2d_673 (Conv2D)            (None, None, None,   16384       ['mixed0[0][0]']
#                                 64)
#
#  batch_normalization_673 (Batch  (None, None, None,   192        ['conv2d_673[0][0]']
#  Normalization)                 64)
#
#  activation_673 (Activation)    (None, None, None,   0           ['batch_normalization_673[0][0]']
#                                 64)
#
#  conv2d_671 (Conv2D)            (None, None, None,   12288       ['mixed0[0][0]']
#                                 48)
#
#  conv2d_674 (Conv2D)            (None, None, None,   55296       ['activation_673[0][0]']
#                                 96)
#
#  batch_normalization_671 (Batch  (None, None, None,   144        ['conv2d_671[0][0]']
#  Normalization)                 48)
#
#  batch_normalization_674 (Batch  (None, None, None,   288        ['conv2d_674[0][0]']
#  Normalization)                 96)
#
#  activation_671 (Activation)    (None, None, None,   0           ['batch_normalization_671[0][0]']
#                                 48)
#
#  activation_674 (Activation)    (None, None, None,   0           ['batch_normalization_674[0][0]']
#                                 96)
#
#  average_pooling2d_68 (AverageP  (None, None, None,   0          ['mixed0[0][0]']
#  ooling2D)                      256)
#
#  conv2d_670 (Conv2D)            (None, None, None,   16384       ['mixed0[0][0]']
#                                 64)
#
#  conv2d_672 (Conv2D)            (None, None, None,   76800       ['activation_671[0][0]']
#                                 64)
#
#  conv2d_675 (Conv2D)            (None, None, None,   82944       ['activation_674[0][0]']
#                                 96)
#
#  conv2d_676 (Conv2D)            (None, None, None,   16384       ['average_pooling2d_68[0][0]']
#                                 64)
#
#  batch_normalization_670 (Batch  (None, None, None,   192        ['conv2d_670[0][0]']
#  Normalization)                 64)
#
#  batch_normalization_672 (Batch  (None, None, None,   192        ['conv2d_672[0][0]']
#  Normalization)                 64)
#
#  batch_normalization_675 (Batch  (None, None, None,   288        ['conv2d_675[0][0]']
#  Normalization)                 96)
#
#  batch_normalization_676 (Batch  (None, None, None,   192        ['conv2d_676[0][0]']
#  Normalization)                 64)
#
#  activation_670 (Activation)    (None, None, None,   0           ['batch_normalization_670[0][0]']
#                                 64)
#
#  activation_672 (Activation)    (None, None, None,   0           ['batch_normalization_672[0][0]']
#                                 64)
#
#  activation_675 (Activation)    (None, None, None,   0           ['batch_normalization_675[0][0]']
#                                 96)
#
#  activation_676 (Activation)    (None, None, None,   0           ['batch_normalization_676[0][0]']
#                                 64)
#
#  mixed1 (Concatenate)           (None, None, None,   0           ['activation_670[0][0]',
#                                 288)                              'activation_672[0][0]',
#                                                                   'activation_675[0][0]',
#                                                                   'activation_676[0][0]']
#
#  conv2d_680 (Conv2D)            (None, None, None,   18432       ['mixed1[0][0]']
#                                 64)
#
#  batch_normalization_680 (Batch  (None, None, None,   192        ['conv2d_680[0][0]']
#  Normalization)                 64)
#
#  activation_680 (Activation)    (None, None, None,   0           ['batch_normalization_680[0][0]']
#                                 64)
#
#  conv2d_678 (Conv2D)            (None, None, None,   13824       ['mixed1[0][0]']
#                                 48)
#
#  conv2d_681 (Conv2D)            (None, None, None,   55296       ['activation_680[0][0]']
#                                 96)
#
#  batch_normalization_678 (Batch  (None, None, None,   144        ['conv2d_678[0][0]']
#  Normalization)                 48)
#
#  batch_normalization_681 (Batch  (None, None, None,   288        ['conv2d_681[0][0]']
#  Normalization)                 96)
#
#  activation_678 (Activation)    (None, None, None,   0           ['batch_normalization_678[0][0]']
#                                 48)
#
#  activation_681 (Activation)    (None, None, None,   0           ['batch_normalization_681[0][0]']
#                                 96)
#
#  average_pooling2d_69 (AverageP  (None, None, None,   0          ['mixed1[0][0]']
#  ooling2D)                      288)
#
#  conv2d_677 (Conv2D)            (None, None, None,   18432       ['mixed1[0][0]']
#                                 64)
#
#  conv2d_679 (Conv2D)            (None, None, None,   76800       ['activation_678[0][0]']
#                                 64)
#
#  conv2d_682 (Conv2D)            (None, None, None,   82944       ['activation_681[0][0]']
#                                 96)
#
#  conv2d_683 (Conv2D)            (None, None, None,   18432       ['average_pooling2d_69[0][0]']
#                                 64)
#
#  batch_normalization_677 (Batch  (None, None, None,   192        ['conv2d_677[0][0]']
#  Normalization)                 64)
#
#  batch_normalization_679 (Batch  (None, None, None,   192        ['conv2d_679[0][0]']
#  Normalization)                 64)
#
#  batch_normalization_682 (Batch  (None, None, None,   288        ['conv2d_682[0][0]']
#  Normalization)                 96)
#
#  batch_normalization_683 (Batch  (None, None, None,   192        ['conv2d_683[0][0]']
#  Normalization)                 64)
#
#  activation_677 (Activation)    (None, None, None,   0           ['batch_normalization_677[0][0]']
#                                 64)
#
#  activation_679 (Activation)    (None, None, None,   0           ['batch_normalization_679[0][0]']
#                                 64)
#
#  activation_682 (Activation)    (None, None, None,   0           ['batch_normalization_682[0][0]']
#                                 96)
#
#  activation_683 (Activation)    (None, None, None,   0           ['batch_normalization_683[0][0]']
#                                 64)
#
#  mixed2 (Concatenate)           (None, None, None,   0           ['activation_677[0][0]',
#                                 288)                              'activation_679[0][0]',
#                                                                   'activation_682[0][0]',
#                                                                   'activation_683[0][0]']
#
#  conv2d_685 (Conv2D)            (None, None, None,   18432       ['mixed2[0][0]']
#                                 64)
#
#  batch_normalization_685 (Batch  (None, None, None,   192        ['conv2d_685[0][0]']
#  Normalization)                 64)
#
#  activation_685 (Activation)    (None, None, None,   0           ['batch_normalization_685[0][0]']
#                                 64)
#
#  conv2d_686 (Conv2D)            (None, None, None,   55296       ['activation_685[0][0]']
#                                 96)
#
#  batch_normalization_686 (Batch  (None, None, None,   288        ['conv2d_686[0][0]']
#  Normalization)                 96)
#
#  activation_686 (Activation)    (None, None, None,   0           ['batch_normalization_686[0][0]']
#                                 96)
#
#  conv2d_684 (Conv2D)            (None, None, None,   995328      ['mixed2[0][0]']
#                                 384)
#
#  conv2d_687 (Conv2D)            (None, None, None,   82944       ['activation_686[0][0]']
#                                 96)
#
#  batch_normalization_684 (Batch  (None, None, None,   1152       ['conv2d_684[0][0]']
#  Normalization)                 384)
#
#  batch_normalization_687 (Batch  (None, None, None,   288        ['conv2d_687[0][0]']
#  Normalization)                 96)
#
#  activation_684 (Activation)    (None, None, None,   0           ['batch_normalization_684[0][0]']
#                                 384)
#
#  activation_687 (Activation)    (None, None, None,   0           ['batch_normalization_687[0][0]']
#                                 96)
#
#  max_pooling2d_30 (MaxPooling2D  (None, None, None,   0          ['mixed2[0][0]']
#  )                              288)
#
#  mixed3 (Concatenate)           (None, None, None,   0           ['activation_684[0][0]',
#                                 768)                              'activation_687[0][0]',
#                                                                   'max_pooling2d_30[0][0]']
#
#  conv2d_692 (Conv2D)            (None, None, None,   98304       ['mixed3[0][0]']
#                                 128)
#
#  batch_normalization_692 (Batch  (None, None, None,   384        ['conv2d_692[0][0]']
#  Normalization)                 128)
#
#  activation_692 (Activation)    (None, None, None,   0           ['batch_normalization_692[0][0]']
#                                 128)
#
#  conv2d_693 (Conv2D)            (None, None, None,   114688      ['activation_692[0][0]']
#                                 128)
#
#  batch_normalization_693 (Batch  (None, None, None,   384        ['conv2d_693[0][0]']
#  Normalization)                 128)
#
#  activation_693 (Activation)    (None, None, None,   0           ['batch_normalization_693[0][0]']
#                                 128)
#
#  conv2d_689 (Conv2D)            (None, None, None,   98304       ['mixed3[0][0]']
#                                 128)
#
#  conv2d_694 (Conv2D)            (None, None, None,   114688      ['activation_693[0][0]']
#                                 128)
#
#  batch_normalization_689 (Batch  (None, None, None,   384        ['conv2d_689[0][0]']
#  Normalization)                 128)
#
#  batch_normalization_694 (Batch  (None, None, None,   384        ['conv2d_694[0][0]']
#  Normalization)                 128)
#
#  activation_689 (Activation)    (None, None, None,   0           ['batch_normalization_689[0][0]']
#                                 128)
#
#  activation_694 (Activation)    (None, None, None,   0           ['batch_normalization_694[0][0]']
#                                 128)
#
#  conv2d_690 (Conv2D)            (None, None, None,   114688      ['activation_689[0][0]']
#                                 128)
#
#  conv2d_695 (Conv2D)            (None, None, None,   114688      ['activation_694[0][0]']
#                                 128)
#
#  batch_normalization_690 (Batch  (None, None, None,   384        ['conv2d_690[0][0]']
#  Normalization)                 128)
#
#  batch_normalization_695 (Batch  (None, None, None,   384        ['conv2d_695[0][0]']
#  Normalization)                 128)
#
#  activation_690 (Activation)    (None, None, None,   0           ['batch_normalization_690[0][0]']
#                                 128)
#
#  activation_695 (Activation)    (None, None, None,   0           ['batch_normalization_695[0][0]']
#                                 128)
#
#  average_pooling2d_70 (AverageP  (None, None, None,   0          ['mixed3[0][0]']
#  ooling2D)                      768)
#
#  conv2d_688 (Conv2D)            (None, None, None,   147456      ['mixed3[0][0]']
#                                 192)
#
#  conv2d_691 (Conv2D)            (None, None, None,   172032      ['activation_690[0][0]']
#                                 192)
#
#  conv2d_696 (Conv2D)            (None, None, None,   172032      ['activation_695[0][0]']
#                                 192)
#
#  conv2d_697 (Conv2D)            (None, None, None,   147456      ['average_pooling2d_70[0][0]']
#                                 192)
#
#  batch_normalization_688 (Batch  (None, None, None,   576        ['conv2d_688[0][0]']
#  Normalization)                 192)
#
#  batch_normalization_691 (Batch  (None, None, None,   576        ['conv2d_691[0][0]']
#  Normalization)                 192)
#
#  batch_normalization_696 (Batch  (None, None, None,   576        ['conv2d_696[0][0]']
#  Normalization)                 192)
#
#  batch_normalization_697 (Batch  (None, None, None,   576        ['conv2d_697[0][0]']
#  Normalization)                 192)
#
#  activation_688 (Activation)    (None, None, None,   0           ['batch_normalization_688[0][0]']
#                                 192)
#
#  activation_691 (Activation)    (None, None, None,   0           ['batch_normalization_691[0][0]']
#                                 192)
#
#  activation_696 (Activation)    (None, None, None,   0           ['batch_normalization_696[0][0]']
#                                 192)
#
#  activation_697 (Activation)    (None, None, None,   0           ['batch_normalization_697[0][0]']
#                                 192)
#
#  mixed4 (Concatenate)           (None, None, None,   0           ['activation_688[0][0]',
#                                 768)                              'activation_691[0][0]',
#                                                                   'activation_696[0][0]',
#                                                                   'activation_697[0][0]']
#
#  conv2d_702 (Conv2D)            (None, None, None,   122880      ['mixed4[0][0]']
#                                 160)
#
#  batch_normalization_702 (Batch  (None, None, None,   480        ['conv2d_702[0][0]']
#  Normalization)                 160)
#
#  activation_702 (Activation)    (None, None, None,   0           ['batch_normalization_702[0][0]']
#                                 160)
#
#  conv2d_703 (Conv2D)            (None, None, None,   179200      ['activation_702[0][0]']
#                                 160)
#
#  batch_normalization_703 (Batch  (None, None, None,   480        ['conv2d_703[0][0]']
#  Normalization)                 160)
#
#  activation_703 (Activation)    (None, None, None,   0           ['batch_normalization_703[0][0]']
#                                 160)
#
#  conv2d_699 (Conv2D)            (None, None, None,   122880      ['mixed4[0][0]']
#                                 160)
#
#  conv2d_704 (Conv2D)            (None, None, None,   179200      ['activation_703[0][0]']
#                                 160)
#
#  batch_normalization_699 (Batch  (None, None, None,   480        ['conv2d_699[0][0]']
#  Normalization)                 160)
#
#  batch_normalization_704 (Batch  (None, None, None,   480        ['conv2d_704[0][0]']
#  Normalization)                 160)
#
#  activation_699 (Activation)    (None, None, None,   0           ['batch_normalization_699[0][0]']
#                                 160)
#
#  activation_704 (Activation)    (None, None, None,   0           ['batch_normalization_704[0][0]']
#                                 160)
#
#  conv2d_700 (Conv2D)            (None, None, None,   179200      ['activation_699[0][0]']
#                                 160)
#
#  conv2d_705 (Conv2D)            (None, None, None,   179200      ['activation_704[0][0]']
#                                 160)
#
#  batch_normalization_700 (Batch  (None, None, None,   480        ['conv2d_700[0][0]']
#  Normalization)                 160)
#
#  batch_normalization_705 (Batch  (None, None, None,   480        ['conv2d_705[0][0]']
#  Normalization)                 160)
#
#  activation_700 (Activation)    (None, None, None,   0           ['batch_normalization_700[0][0]']
#                                 160)
#
#  activation_705 (Activation)    (None, None, None,   0           ['batch_normalization_705[0][0]']
#                                 160)
#
#  average_pooling2d_71 (AverageP  (None, None, None,   0          ['mixed4[0][0]']
#  ooling2D)                      768)
#
#  conv2d_698 (Conv2D)            (None, None, None,   147456      ['mixed4[0][0]']
#                                 192)
#
#  conv2d_701 (Conv2D)            (None, None, None,   215040      ['activation_700[0][0]']
#                                 192)
#
#  conv2d_706 (Conv2D)            (None, None, None,   215040      ['activation_705[0][0]']
#                                 192)
#
#  conv2d_707 (Conv2D)            (None, None, None,   147456      ['average_pooling2d_71[0][0]']
#                                 192)
#
#  batch_normalization_698 (Batch  (None, None, None,   576        ['conv2d_698[0][0]']
#  Normalization)                 192)
#
#  batch_normalization_701 (Batch  (None, None, None,   576        ['conv2d_701[0][0]']
#  Normalization)                 192)
#
# ...
#
#  average_pooling2d_74 (AverageP  (None, None, None,   0          ['mixed8[0][0]']
#  ooling2D)                      1280)
#
#  conv2d_734 (Conv2D)            (None, None, None,   409600      ['mixed8[0][0]']
#                                 320)
#
#  batch_normalization_736 (Batch  (None, None, None,   1152       ['conv2d_736[0][0]']
#  Normalization)                 384)
#
#  batch_normalization_737 (Batch  (None, None, None,   1152       ['conv2d_737[0][0]']
#  Normalization)                 384)
#
#  batch_normalization_740 (Batch  (None, None, None,   1152       ['conv2d_740[0][0]']
#  Normalization)                 384)
#
#  batch_normalization_741 (Batch  (None, None, None,   1152       ['conv2d_741[0][0]']
#  Normalization)                 384)
#
#  conv2d_742 (Conv2D)            (None, None, None,   245760      ['average_pooling2d_74[0][0]']
#                                 192)
#
#  batch_normalization_734 (Batch  (None, None, None,   960        ['conv2d_734[0][0]']
#  Normalization)                 320)
#
#  activation_736 (Activation)    (None, None, None,   0           ['batch_normalization_736[0][0]']
#                                 384)
#
#  activation_737 (Activation)    (None, None, None,   0           ['batch_normalization_737[0][0]']
#                                 384)
#
#  activation_740 (Activation)    (None, None, None,   0           ['batch_normalization_740[0][0]']
#                                 384)
#
#  activation_741 (Activation)    (None, None, None,   0           ['batch_normalization_741[0][0]']
#                                 384)
#
#  batch_normalization_742 (Batch  (None, None, None,   576        ['conv2d_742[0][0]']
#  Normalization)                 192)
#
#  activation_734 (Activation)    (None, None, None,   0           ['batch_normalization_734[0][0]']
#                                 320)
#
#  mixed9_0 (Concatenate)         (None, None, None,   0           ['activation_736[0][0]',
#                                 768)                              'activation_737[0][0]']
#
#  concatenate_14 (Concatenate)   (None, None, None,   0           ['activation_740[0][0]',
#                                 768)                              'activation_741[0][0]']
#
#  activation_742 (Activation)    (None, None, None,   0           ['batch_normalization_742[0][0]']
#                                 192)
#
#  mixed9 (Concatenate)           (None, None, None,   0           ['activation_734[0][0]',
#                                 2048)                             'mixed9_0[0][0]',
#                                                                   'concatenate_14[0][0]',
#                                                                   'activation_742[0][0]']
#
#  conv2d_747 (Conv2D)            (None, None, None,   917504      ['mixed9[0][0]']
#                                 448)
#
#  batch_normalization_747 (Batch  (None, None, None,   1344       ['conv2d_747[0][0]']
#  Normalization)                 448)
#
#  activation_747 (Activation)    (None, None, None,   0           ['batch_normalization_747[0][0]']
#                                 448)
#
#  conv2d_744 (Conv2D)            (None, None, None,   786432      ['mixed9[0][0]']
#                                 384)
#
#  conv2d_748 (Conv2D)            (None, None, None,   1548288     ['activation_747[0][0]']
#                                 384)
#
#  batch_normalization_744 (Batch  (None, None, None,   1152       ['conv2d_744[0][0]']
#  Normalization)                 384)
#
#  batch_normalization_748 (Batch  (None, None, None,   1152       ['conv2d_748[0][0]']
#  Normalization)                 384)
#
#  activation_744 (Activation)    (None, None, None,   0           ['batch_normalization_744[0][0]']
#                                 384)
#
#  activation_748 (Activation)    (None, None, None,   0           ['batch_normalization_748[0][0]']
#                                 384)
#
#  conv2d_745 (Conv2D)            (None, None, None,   442368      ['activation_744[0][0]']
#                                 384)
#
#  conv2d_746 (Conv2D)            (None, None, None,   442368      ['activation_744[0][0]']
#                                 384)
#
#  conv2d_749 (Conv2D)            (None, None, None,   442368      ['activation_748[0][0]']
#                                 384)
#
#  conv2d_750 (Conv2D)            (None, None, None,   442368      ['activation_748[0][0]']
#                                 384)
#
#  average_pooling2d_75 (AverageP  (None, None, None,   0          ['mixed9[0][0]']
#  ooling2D)                      2048)
#
#  conv2d_743 (Conv2D)            (None, None, None,   655360      ['mixed9[0][0]']
#                                 320)
#
#  batch_normalization_745 (Batch  (None, None, None,   1152       ['conv2d_745[0][0]']
#  Normalization)                 384)
#
#  batch_normalization_746 (Batch  (None, None, None,   1152       ['conv2d_746[0][0]']
#  Normalization)                 384)
#
#  batch_normalization_749 (Batch  (None, None, None,   1152       ['conv2d_749[0][0]']
#  Normalization)                 384)
#
#  batch_normalization_750 (Batch  (None, None, None,   1152       ['conv2d_750[0][0]']
#  Normalization)                 384)
#
#  conv2d_751 (Conv2D)            (None, None, None,   393216      ['average_pooling2d_75[0][0]']
#                                 192)
#
#  batch_normalization_743 (Batch  (None, None, None,   960        ['conv2d_743[0][0]']
#  Normalization)                 320)
#
#  activation_745 (Activation)    (None, None, None,   0           ['batch_normalization_745[0][0]']
#                                 384)
#
#  activation_746 (Activation)    (None, None, None,   0           ['batch_normalization_746[0][0]']
#                                 384)
#
#  activation_749 (Activation)    (None, None, None,   0           ['batch_normalization_749[0][0]']
#                                 384)
#
#  activation_750 (Activation)    (None, None, None,   0           ['batch_normalization_750[0][0]']
#                                 384)
#
#  batch_normalization_751 (Batch  (None, None, None,   576        ['conv2d_751[0][0]']
#  Normalization)                 192)
#
#  activation_743 (Activation)    (None, None, None,   0           ['batch_normalization_743[0][0]']
#                                 320)
#
#  mixed9_1 (Concatenate)         (None, None, None,   0           ['activation_745[0][0]',
#                                 768)                              'activation_746[0][0]']
#
#  concatenate_15 (Concatenate)   (None, None, None,   0           ['activation_749[0][0]',
#                                 768)                              'activation_750[0][0]']
#
#  activation_751 (Activation)    (None, None, None,   0           ['batch_normalization_751[0][0]']
#                                 192)
#
#  mixed10 (Concatenate)          (None, None, None,   0           ['activation_743[0][0]',
#                                 2048)                             'mixed9_1[0][0]',
#                                                                   'concatenate_15[0][0]',
#                                                                   'activation_751[0][0]']
#
#  global_average_pooling2d_3 (Gl  (None, 2048)        0           ['mixed10[0][0]']
#  obalAveragePooling2D)
#
#  dense_7 (Dense)                (None, 62)           127038      ['global_average_pooling2d_3[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 21,929,822
# Trainable params: 21,895,390
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %%
for layer in base_model.layers:

    layer.trainable = False

model_inceptionv3.compile(loss="sparse_categorical_crossentropy", optimizer="nadam",

              metrics=["accuracy"])

 

check_best_cb = tf.keras.callbacks.ModelCheckpoint("inceptionv3_best_nadam.h5",save_best_only=True)

check_last_cb = tf.keras.callbacks.ModelCheckpoint("inceptionv3_last_nadam.h5",save_best_only=False)

 

history = model_inceptionv3.fit(train_set,

                    steps_per_epoch=int(train_size / batch_size),

                    validation_data=valid_set,

                    validation_steps=int(valid_size / batch_size),

                    epochs=2,callbacks=[check_best_cb,check_last_cb])
# Out:
# Epoch 1/2
# 41552/41552 [==============================] - 1980s 48ms/step - loss: 0.6224 - accuracy: 0.8075 - val_loss: 3.8910 - val_accuracy: 0.5528
# Epoch 2/2
# 41552/41552 [==============================] - 1954s 47ms/step - loss: 0.5103 - accuracy: 0.8375 - val_loss: 4.3292 - val_accuracy: 0.5685

# %%
import datetime as dt

for layer in base_model.layers:

    layer.trainable = True

model_inceptionv3.compile(loss="sparse_categorical_crossentropy", optimizer="nadam",

              metrics=["accuracy"])

 

check_best_cb = tf.keras.callbacks.ModelCheckpoint("inceptionv3_best_nadam.h5",save_best_only=True)

check_last_cb = tf.keras.callbacks.ModelCheckpoint("inceptionv3_last_nadam.h5",save_best_only=False)

logs = "logs/" + dt.datetime.now().strftime("inceptionv3%Y%m%d-%H%M%S")

tboard_callback = tf.keras.callbacks.TensorBoard(log_dir = logs,

                                                 histogram_freq = 1,

                                                 profile_batch = '500,520')

early_stop_cb=tf.keras.callbacks.EarlyStopping(patience=10,restore_best_weights=True)
 

history = model_inceptionv3.fit(train_set,

                    steps_per_epoch=int(train_size / batch_size),

                    validation_data=valid_set,

                    validation_steps=int(valid_size / batch_size),

                    epochs=300,callbacks=[check_best_cb,check_last_cb,tboard_callback,early_stop_cb])
# Out:
# Epoch 1/300
# 41552/41552 [==============================] - 9143s 220ms/step - loss: 0.3321 - accuracy: 0.8798 - val_loss: 3.1828 - val_accuracy: 0.6303
# Epoch 2/300
# 41552/41552 [==============================] - 9150s 220ms/step - loss: 0.2443 - accuracy: 0.9055 - val_loss: 4.8386 - val_accuracy: 0.5526
# Epoch 3/300
# 41552/41552 [==============================] - 9165s 221ms/step - loss: 0.1984 - accuracy: 0.9206 - val_loss: 5.7495 - val_accuracy: 0.5368
# Epoch 4/300
# 41552/41552 [==============================] - 9164s 221ms/step - loss: 0.1188 - accuracy: 0.9533 - val_loss: 6.7158 - val_accuracy: 0.5542
# Epoch 5/300
# 41552/41552 [==============================] - 9164s 221ms/step - loss: 0.0780 - accuracy: 0.9698 - val_loss: 7.1416 - val_accuracy: 0.5452
# Epoch 6/300
# 41552/41552 [==============================] - 9165s 221ms/step - loss: 0.0519 - accuracy: 0.9806 - val_loss: 10.0044 - val_accuracy: 0.5114
# Epoch 7/300
# 41552/41552 [==============================] - 9166s 221ms/step - loss: 0.0406 - accuracy: 0.9852 - val_loss: 6.7585 - val_accuracy: 0.5659
# Epoch 8/300
# 41552/41552 [==============================] - 9165s 221ms/step - loss: 0.0334 - accuracy: 0.9880 - val_loss: 7.5021 - val_accuracy: 0.5530
# Epoch 9/300
# 41552/41552 [==============================] - 9164s 221ms/step - loss: 0.0286 - accuracy: 0.9898 - val_loss: 8.5772 - val_accuracy: 0.5815
# Epoch 10/300
# 41552/41552 [==============================] - 9149s 220ms/step - loss: 0.0229 - accuracy: 0.9919 - val_loss: 6.6586 - val_accuracy: 0.5830
# Epoch 11/300
# 41552/41552 [==============================] - 9154s 220ms/step - loss: 0.0218 - accuracy: 0.9924 - val_loss: 7.3626 - val_accuracy: 0.5655
