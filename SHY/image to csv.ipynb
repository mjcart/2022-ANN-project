# %% [markdown]
# convert image to csv // 이승훈

# %%
import numpy as np
import os
import cv2 as cv
import csv
from sklearn import utils 
from tqdm.notebook import tqdm

pr_dir='C:/ANN/pr'

def labeling(img):
    class_name=img.split('.')[0]
    return class_name

#혹시 class_name 반환으로 안될시
    """if class_name=='0':
        return 0
    elif class_name=='1':
        return 1
    elif class_name=='2':
        return 2
    elif class_name=='1':
        return 3
    elif class_name=='1':
        return 4
    elif class_name=='1':
        return 5
    elif class_name=='1':
        return 6
    elif class_name=='1':
        return 7
    elif class_name=='1':
        return 8
    elif class_name=='1':
        return 9
    elif class_name=='a':
        return 'a'
    elif class_name=='b':
        return 'b'
    elif class_name=='c':
        return 'c'
    elif class_name=='d':
        return 'd'
    elif class_name=='e':
        return 'e'
    elif class_name=='f':
        return 'f'
    elif class_name=='g':
        return 'g'
    elif class_name=='h':
        return 'h'
    elif class_name=='i':
        return 'i'
    elif class_name=='j':
        return 'j'
    elif class_name=='k':
        return 'k'
    elif class_name=='l':
        return 'l'
    elif class_name=='m':
        return 'm'
    elif class_name=='n':
        return 'n'
    elif class_name=='o':
        return 'o'
    elif class_name=='p':
        return 'p'
    elif class_name=='q':
        return 'q'
    elif class_name=='r':
        return 'r'
    elif class_name=='s':
        return 's'
    elif class_name=='t':
        return 't'
    elif class_name=='u':
        return 'u'
    elif class_name=='v':
        return 'v'
    elif class_name=='w':
        return 'w'
    elif class_name=='x':
        return 'x'
    elif class_name=='y':
        return 'y'
    elif class_name=='z':
        return 'z'
    elif class_name=='c':
        return 'c'
    elif class_name=='A':
        return 'A'
    elif class_name=='B':
        return 'B'
    elif class_name=='C':
        return 'C'
    elif class_name=='D':
        return 'D'
    elif class_name=='E':
        return 'E'
    elif class_name=='F':
        return 'F'
    elif class_name=='G':
        return 'G'
    elif class_name=='H':
        return 'H'
    elif class_name=='I':
        return 'I'
    elif class_name=='J':
        return 'J'
    elif class_name=='K':
        return 'K'
    elif class_name=='L':
        return 'L'
    elif class_name=='M':
        return 'M'
    elif class_name=='N':
        return 'N'
    elif class_name=='O':
        return 'O'
    elif class_name=='P':
        return 'P'
    elif class_name=='Q':
        return 'Q'
    elif class_name=='R':
        return 'R'
    elif class_name=='S':
        return 'S'
    elif class_name=='T':
        return 'T'
    elif class_name=='U':
        return 'U'
    elif class_name=='V':
        return 'V'
    elif class_name=='W':
        return 'W'
    elif class_name=='X':
        return 'X'
    elif class_name=='Y':
        return 'Y'
    elif class_name=='Z':
        return 'Z'
    """

    
    




for img in tqdm(os.listdir(pr_dir),total=len(os.listdir(pr_dir)),position=0,leave=True):

    
    label_data=labeling(img)
    
    img_path=os.path.join(pr_dir,img)
    
    img_data=cv.imread(img_path,cv.IMREAD_GRAYSCALE)
    img_data_f=img_data.flatten()
    image_data_b=img_data_f.tolist()
    image_data=list(map(str,image_data_b))
    #image_data=image_data.flatten()


    
    image_data.insert(0,label_data)
    #x_data.append(label_data)


    print(image_data)
    
    with open('test.csv','a',newline='') as f:
        write=csv.writer(f)
        write.writerow(image_data)


    
    #with open('test.csv', 'w',newline='') as f: 
     #   write=csv.writer(f)
      #  write.writerows(image_data)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# ...
