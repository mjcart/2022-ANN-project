# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
print("sklearn version: ", sklearn.__version__)
assert sklearn.__version__ >= "0.20"

try:
    # %tensorflow_version only exists in Colab.
    # %tensorflow_version 2.x
    IS_COLAB = True
except Exception:
    IS_COLAB = False

# TensorFlow ≥2.0 is required
import tensorflow as tf
# !pip install tensorflow_addons
import tensorflow_addons as tfa
from tensorflow import keras
print("TF version: ", tf.__version__)
assert tf.__version__ >= "2.0"

if not tf.config.list_physical_devices('GPU'):
    print("No GPU was detected. CNNs can be very slow without a GPU.")
    if IS_COLAB:
        print("Go to Runtime > Change runtime and select a GPU hardware accelerator.")

# GPU test
print("GPU installed: ",tf.test.is_built_with_gpu_support())

# To prevent "CUDNN_STATUS_ALLOC_FAILED" error with GPUs
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
    
# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
np.random.seed(42)
tf.random.set_seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "cnn"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)
    
# Ignore useless warnings (see SciPy issue #5998)
import warnings
warnings.filterwarnings(action="ignore", message="^internal gelsd")    

from tensorflow.python.keras.utils.data_utils import Sequence
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# sklearn version:  1.0.2
# Requirement already satisfied: tensorflow_addons in /opt/conda/lib/python3.9/site-packages (0.17.0)
# Requirement already satisfied: typeguard>=2.7 in /opt/conda/lib/python3.9/site-packages (from tensorflow_addons) (2.13.3)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.9/site-packages (from tensorflow_addons) (21.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.9/site-packages (from packaging->tensorflow_addons) (3.0.3)
# TF version:  2.8.0
# GPU installed:  True
# 4 Physical GPUs, 4 Logical GPUs
# 2022-06-06 12:37:31.830949: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-06 12:37:34.402818: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14791 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:19:00.0, compute capability: 7.5
# 2022-06-06 12:37:34.403862: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 14791 MB memory:  -> device: 1, name: Quadro RTX 5000, pci bus id: 0000:1a:00.0, compute capability: 7.5
# 2022-06-06 12:37:34.404607: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 3220 MB memory:  -> device: 2, name: Quadro RTX 5000, pci bus id: 0000:67:00.0, compute capability: 7.5
# 2022-06-06 12:37:34.405324: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 3086 MB memory:  -> device: 3, name: Quadro RTX 5000, pci bus id: 0000:68:00.0, compute capability: 7.5

# %%
X_train=np.uint8(np.load('./X_train_aug.npy'))
y_train=np.uint8(np.load('./y_train_aug.npy'))
X_valid=np.uint8(np.load('./X_valid.npy'))
y_valid=np.uint8(np.load('./y_valid.npy'))

# %%
X_valid=tf.reshape(X_valid,[-1,28,28,1])
X_valid_resize=np.uint8(tf.image.resize(X_valid, [32, 32]))
X_train.shape,X_valid_resize.shape,X_train.dtype
# Out:
# ((1074263, 32, 32, 1), (164015, 32, 32, 1), dtype('uint8'))

# %%
#황성현 전민재 He_normal initializer
class Inveted_Residual_Block(keras.layers.Layer):
    def __init__(self,c,s=1,t=1,n=1,**kwargs):
        super().__init__(**kwargs)
        self.activation = keras.layers.ReLU(max_value=6)
        self.main_layers = [
            
            ]
        self.strides_layers=[
           ]
        self.s=s
        self.t=t
        self.c=c
        self.n=n
        
    def build(self,batch_input_shape):
        print(self.name,": batch_input_shape =",batch_input_shape)
        initializer = tf.keras.initializers.HeNormal()
        self.main_layers = [
            keras.layers.BatchNormalization(),
            keras.layers.Conv2D(filters=batch_input_shape[-1]*self.t, kernel_size=1,strides=1, kernel_initializer=initializer,
                                padding="SAME", activation=self.activation),
            keras.layers.BatchNormalization(),
            keras.layers.DepthwiseConv2D(kernel_size=3, strides=1,padding="SAME", activation=self.activation,kernel_initializer=initializer),
            keras.layers.BatchNormalization(),
            keras.layers.Conv2D(filters=self.c,kernel_size=1, strides=1,padding="SAME", activation=self.activation,kernel_initializer=initializer),
            ]
        self.strides_layers=[
            keras.layers.BatchNormalization(),
            keras.layers.Conv2D(filters=batch_input_shape[-1]*self.t, kernel_size=1,strides=1,kernel_initializer=initializer,
                                padding="SAME", activation=self.activation),
            keras.layers.BatchNormalization(),
            keras.layers.DepthwiseConv2D(kernel_size=3, strides=self.s,padding="SAME",activation=self.activation,kernel_initializer=initializer),
            keras.layers.BatchNormalization(),
            keras.layers.Conv2D(filters=self.c, kernel_size=1,strides=1,padding="SAME",activation=self.activation,kernel_initializer=initializer),
        ]

    def call(self, inputs):
        Z = inputs
        
        for n in range(0,self.n):
            if n == 0:
                for layer in self.strides_layers:
                    Z = layer(Z)
            else:
                skip_Z = Z
                for layer in self.main_layers:
                    Z = layer(Z)
                
                Z += skip_Z
    
        return Z
    
    def get_config(self):
        base=super().get_config()
        return{**base,"s":self.s,"t":self.t,"c":self.c,"n":self.n}

# %%
    #황성현 전민재 IRB6512
    #multygpu


    n_classes=62
    smv2_l=keras.models.Sequential([
        keras.layers.BatchNormalization(input_shape=[32,32,1]),
        keras.layers.Conv2D(filters=32,kernel_size=3,strides=2,padding="same",activation="relu"),
        Inveted_Residual_Block(t=1,c=16,n=1,s=1,name="IRB1"),
        Inveted_Residual_Block(t=4,c=16,n=2,s=2,name="IRB2"),
        Inveted_Residual_Block(t=8,c=32,n=2,s=2,name="IRB3"),
        Inveted_Residual_Block(t=8,c=64,n=2,s=2,name="IRB4"),
        Inveted_Residual_Block(t=8,c=128,n=1,s=2,name="IRB5"),
        Inveted_Residual_Block(t=8,c=512,n=1,s=1,name="IRB6"),
        keras.layers.ReLU(max_value=6),
        keras.layers.GlobalAveragePooling2D(),
        keras.layers.BatchNormalization(),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(n_classes,activation="softmax")
    ])
    smv2_l.summary()
    opt = tf.keras.optimizers.Adam(learning_rate=0.0003)
    batch_size=128
    smv2_l.compile(loss="sparse_categorical_crossentropy",optimizer=opt,metrics=["accuracy"])
# Out:
# IRB1 : batch_input_shape = (None, 16, 16, 32)
# IRB2 : batch_input_shape = (None, 16, 16, 16)
# IRB3 : batch_input_shape = (None, 8, 8, 16)
# IRB4 : batch_input_shape = (None, 4, 4, 32)
# IRB5 : batch_input_shape = (None, 2, 2, 64)
# IRB6 : batch_input_shape = (None, 1, 1, 128)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 32, 32, 1)        4
#  ormalization)
#
#  conv2d (Conv2D)             (None, 16, 16, 32)        320
#
#  IRB1 (Inveted_Residual_Bloc  (None, 16, 16, 16)       2288
#  k)
#
#  IRB2 (Inveted_Residual_Bloc  (None, 8, 8, 16)         6688
#  k)
#
#  IRB3 (Inveted_Residual_Bloc  (None, 4, 4, 32)         19456
#  k)
#
#  IRB4 (Inveted_Residual_Bloc  (None, 2, 2, 64)         67584
#  k)
#
#  IRB5 (Inveted_Residual_Bloc  (None, 1, 1, 128)        108416
#  k)
#
#  IRB6 (Inveted_Residual_Bloc  (None, 1, 1, 512)        675840
#  k)
#
#  re_lu_6 (ReLU)              (None, 1, 1, 512)         0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 62)                31806
#
# =================================================================
# Total params: 914,450
# Trainable params: 902,768
# Non-trainable params: 11,682
# _________________________________________________________________

# %%
#전민재
class OneCycleScheduler(keras.callbacks.Callback):
    def __init__(self, iterations, max_rate, start_rate=None,
                 last_iterations=None, last_rate=None):
        self.iterations = iterations
        self.max_rate = max_rate
        self.start_rate = start_rate or max_rate / 10
        self.last_iterations = last_iterations or iterations // 10 + 1
        self.half_iteration = (iterations - self.last_iterations) // 2
        self.last_rate = last_rate or self.start_rate / 1000
        self.iteration = 0
    def _interpolate(self, iter1, iter2, rate1, rate2):
        return ((rate2 - rate1) * (self.iteration - iter1)
                / (iter2 - iter1) + rate1)
    def on_batch_begin(self, batch, logs):
        if self.iteration < self.half_iteration:
            rate = self._interpolate(0, self.half_iteration, self.start_rate, self.max_rate)
        elif self.iteration < 2 * self.half_iteration:
            rate = self._interpolate(self.half_iteration, 2 * self.half_iteration,
                                     self.max_rate, self.start_rate)
        else:
            rate = self._interpolate(2 * self.half_iteration, self.iterations,
                                     self.start_rate, self.last_rate)
            rate = max(rate, self.last_rate)
        self.iteration += 1
        K.set_value(self.model.optimizer.lr, rate)

# %%
#황성현 전민재
from datetime import datetime
K = keras.backend
logs = "logs/" + datetime.now().strftime("SMV2L_lrsch_onecycle_aug_dropout_128_he_irb6_512_epoch70%Y%m%d-%H%M%S")
onecycle = OneCycleScheduler(len(X_train) // batch_size * 70, max_rate=0.003)
tboard_callback = tf.keras.callbacks.TensorBoard(log_dir = logs,
                                                 histogram_freq = 1,
                                                 profile_batch = '500,520')
check_best_cb=tf.keras.callbacks.ModelCheckpoint(filepath="smv2l_adam_best_lrsch_onecycle_aug_dropout_128_he_irb6_512_epoch70.h5",save_best_only=True)

history=smv2_l.fit(X_train,y_train,validation_data=(X_valid_resize,y_valid),batch_size = batch_size, epochs=70,callbacks=[tboard_callback, check_best_cb,onecycle])
# Out:
# 2022-06-06 12:37:41.419218: I tensorflow/core/profiler/lib/profiler_session.cc:110] Profiler session initializing.
# 2022-06-06 12:37:41.419274: I tensorflow/core/profiler/lib/profiler_session.cc:125] Profiler session started.
# 2022-06-06 12:37:41.419341: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1630] Profiler found 4 GPUs
# 2022-06-06 12:37:41.420026: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcupti.so.11.2'; dlerror: libcupti.so.11.2: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2022-06-06 12:37:42.167226: I tensorflow/core/profiler/lib/profiler_session.cc:143] Profiler session tear down.
# 2022-06-06 12:37:42.167454: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1764] CUPTI activity buffer flushed
# 2022-06-06 12:37:42.256896: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 1100045312 exceeds 10% of free system memory.
# 2022-06-06 12:37:43.028095: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 1100045312 exceeds 10% of free system memory.
# Epoch 1/70
# 2022-06-06 12:37:46.110551: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8204
#  498/8393 [>.............................] - ETA: 3:05 - loss: 4.5981 - accuracy: 0.0599
# 2022-06-06 12:37:59.377955: I tensorflow/core/profiler/lib/profiler_session.cc:110] Profiler session initializing.
# 2022-06-06 12:37:59.378008: I tensorflow/core/profiler/lib/profiler_session.cc:125] Profiler session started.
#  518/8393 [>.............................] - ETA: 3:20 - loss: 4.5710 - accuracy: 0.0614
# 2022-06-06 12:38:00.928712: I tensorflow/core/profiler/lib/profiler_session.cc:67] Profiler session collecting data.
# 2022-06-06 12:38:00.929459: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1764] CUPTI activity buffer flushed
# 2022-06-06 12:38:01.105451: I tensorflow/core/profiler/internal/gpu/cupti_collector.cc:521]  GpuTracer has collected 14974 callback api events and 15049 activity events.
# 2022-06-06 12:38:01.365427: I tensorflow/core/profiler/lib/profiler_session.cc:143] Profiler session tear down.
# 2022-06-06 12:38:01.676740: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: logs/SMV2L_lrsch_onecycle_aug_dropout_128_he_irb6_512_epoch7020220606-123741/plugins/profile/2022_06_06_12_38_01
#
# 2022-06-06 12:38:01.898697: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for trace.json.gz to logs/SMV2L_lrsch_onecycle_aug_dropout_128_he_irb6_512_epoch7020220606-123741/plugins/profile/2022_06_06_12_38_01/a58a2589147d.trace.json.gz
#  523/8393 [>.............................] - ETA: 3:40 - loss: 4.5640 - accuracy: 0.0619
# 2022-06-06 12:38:02.161314: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: logs/SMV2L_lrsch_onecycle_aug_dropout_128_he_irb6_512_epoch7020220606-123741/plugins/profile/2022_06_06_12_38_01
#
# 2022-06-06 12:38:02.168571: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for memory_profile.json.gz to logs/SMV2L_lrsch_onecycle_aug_dropout_128_he_irb6_512_epoch7020220606-123741/plugins/profile/2022_06_06_12_38_01/a58a2589147d.memory_profile.json.gz
# 2022-06-06 12:38:02.174444: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: logs/SMV2L_lrsch_onecycle_aug_dropout_128_he_irb6_512_epoch7020220606-123741/plugins/profile/2022_06_06_12_38_01
# Dumped tool data for xplane.pb to logs/SMV2L_lrsch_onecycle_aug_dropout_128_he_irb6_512_epoch7020220606-123741/plugins/profile/2022_06_06_12_38_01/a58a2589147d.xplane.pb
# Dumped tool data for overview_page.pb to logs/SMV2L_lrsch_onecycle_aug_dropout_128_he_irb6_512_epoch7020220606-123741/plugins/profile/2022_06_06_12_38_01/a58a2589147d.overview_page.pb
# Dumped tool data for input_pipeline.pb to logs/SMV2L_lrsch_onecycle_aug_dropout_128_he_irb6_512_epoch7020220606-123741/plugins/profile/2022_06_06_12_38_01/a58a2589147d.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to logs/SMV2L_lrsch_onecycle_aug_dropout_128_he_irb6_512_epoch7020220606-123741/plugins/profile/2022_06_06_12_38_01/a58a2589147d.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to logs/SMV2L_lrsch_onecycle_aug_dropout_128_he_irb6_512_epoch7020220606-123741/plugins/profile/2022_06_06_12_38_01/a58a2589147d.kernel_stats.pb
# 8393/8393 [==============================] - 218s 26ms/step - loss: 1.4383 - accuracy: 0.5989 - val_loss: 0.4854 - val_accuracy: 0.8256
# Epoch 2/70
# 8393/8393 [==============================] - 212s 25ms/step - loss: 0.4912 - accuracy: 0.8251 - val_loss: 0.4569 - val_accuracy: 0.8336
# Epoch 3/70
# 8393/8393 [==============================] - 212s 25ms/step - loss: 0.4356 - accuracy: 0.8416 - val_loss: 0.3971 - val_accuracy: 0.8529
# Epoch 4/70
# 8393/8393 [==============================] - 215s 26ms/step - loss: 0.4138 - accuracy: 0.8478 - val_loss: 0.4007 - val_accuracy: 0.8518
# Epoch 5/70
# 8393/8393 [==============================] - 212s 25ms/step - loss: 0.4009 - accuracy: 0.8516 - val_loss: 0.3795 - val_accuracy: 0.8598
# Epoch 6/70
# 8393/8393 [==============================] - 212s 25ms/step - loss: 0.3927 - accuracy: 0.8543 - val_loss: 0.3760 - val_accuracy: 0.8616
# Epoch 7/70
# 8393/8393 [==============================] - 212s 25ms/step - loss: 0.3868 - accuracy: 0.8560 - val_loss: 0.3712 - val_accuracy: 0.8629
# Epoch 8/70
# 8393/8393 [==============================] - 212s 25ms/step - loss: 0.3820 - accuracy: 0.8575 - val_loss: 0.3772 - val_accuracy: 0.8598
# Epoch 9/70
# 8393/8393 [==============================] - 212s 25ms/step - loss: 0.3788 - accuracy: 0.8587 - val_loss: 0.3638 - val_accuracy: 0.8637
# Epoch 10/70
# 8393/8393 [==============================] - 212s 25ms/step - loss: 0.3751 - accuracy: 0.8600 - val_loss: 0.3697 - val_accuracy: 0.8641
# Epoch 11/70
# 8393/8393 [==============================] - 215s 26ms/step - loss: 0.3726 - accuracy: 0.8603 - val_loss: 0.7017 - val_accuracy: 0.7996
# Epoch 12/70
# 8393/8393 [==============================] - 212s 25ms/step - loss: 0.3709 - accuracy: 0.8611 - val_loss: 0.4187 - val_accuracy: 0.8519
# Epoch 13/70
# 8393/8393 [==============================] - 212s 25ms/step - loss: 0.3685 - accuracy: 0.8620 - val_loss: 0.3865 - val_accuracy: 0.8569
# Epoch 14/70
# 8393/8393 [==============================] - 213s 25ms/step - loss: 0.3670 - accuracy: 0.8626 - val_loss: 0.3700 - val_accuracy: 0.8619
# Epoch 15/70
# 8393/8393 [==============================] - 212s 25ms/step - loss: 0.3661 - accuracy: 0.8627 - val_loss: 0.4474 - val_accuracy: 0.8419
# Epoch 16/70
# 8393/8393 [==============================] - 212s 25ms/step - loss: 0.3647 - accuracy: 0.8630 - val_loss: 0.3675 - val_accuracy: 0.8631
# Epoch 17/70
# 8393/8393 [==============================] - 212s 25ms/step - loss: 0.3647 - accuracy: 0.8629 - val_loss: 0.8920 - val_accuracy: 0.7582
# Epoch 18/70
# 8393/8393 [==============================] - 214s 25ms/step - loss: 0.3640 - accuracy: 0.8634 - val_loss: 0.5996 - val_accuracy: 0.8050
# Epoch 19/70
# 8393/8393 [==============================] - 220s 26ms/step - loss: 0.3654 - accuracy: 0.8631 - val_loss: 0.3697 - val_accuracy: 0.8618
# Epoch 20/70
# 8393/8393 [==============================] - 216s 26ms/step - loss: 0.3668 - accuracy: 0.8626 - val_loss: 0.4507 - val_accuracy: 0.8293
# Epoch 21/70
# 8393/8393 [==============================] - 216s 26ms/step - loss: 0.3674 - accuracy: 0.8624 - val_loss: 0.3738 - val_accuracy: 0.8622
# Epoch 22/70
# 8393/8393 [==============================] - 216s 26ms/step - loss: 0.3702 - accuracy: 0.8620 - val_loss: 0.4159 - val_accuracy: 0.8493
# Epoch 23/70
# 8393/8393 [==============================] - 216s 26ms/step - loss: 0.3724 - accuracy: 0.8608 - val_loss: 0.4551 - val_accuracy: 0.8336
# Epoch 24/70
# 8393/8393 [==============================] - 215s 26ms/step - loss: 0.3758 - accuracy: 0.8603 - val_loss: 0.3845 - val_accuracy: 0.8561
# Epoch 25/70
# 8393/8393 [==============================] - 216s 26ms/step - loss: 0.3782 - accuracy: 0.8596 - val_loss: 0.3817 - val_accuracy: 0.8596
# Epoch 26/70
# 8393/8393 [==============================] - 223s 27ms/step - loss: 0.3818 - accuracy: 0.8587 - val_loss: 0.4553 - val_accuracy: 0.8351
# Epoch 27/70
# 8393/8393 [==============================] - 220s 26ms/step - loss: 0.3871 - accuracy: 0.8571 - val_loss: 2.8589 - val_accuracy: 0.3757
# Epoch 28/70
# 8393/8393 [==============================] - 220s 26ms/step - loss: 0.3907 - accuracy: 0.8564 - val_loss: 0.4143 - val_accuracy: 0.8476
# Epoch 29/70
# 8393/8393 [==============================] - 220s 26ms/step - loss: 0.3977 - accuracy: 0.8542 - val_loss: 0.4258 - val_accuracy: 0.8471
# Epoch 30/70
# 8393/8393 [==============================] - 220s 26ms/step - loss: 0.4052 - accuracy: 0.8524 - val_loss: 0.4218 - val_accuracy: 0.8508
# Epoch 31/70
# 8393/8393 [==============================] - 221s 26ms/step - loss: 0.4134 - accuracy: 0.8499 - val_loss: 2.2698 - val_accuracy: 0.4630
# Epoch 32/70
# 8393/8393 [==============================] - 221s 26ms/step - loss: 0.4234 - accuracy: 0.8474 - val_loss: 0.8014 - val_accuracy: 0.7637
# Epoch 33/70
# 8393/8393 [==============================] - 223s 27ms/step - loss: 0.4272 - accuracy: 0.8458 - val_loss: 0.4190 - val_accuracy: 0.8474
# Epoch 34/70
# 8393/8393 [==============================] - 220s 26ms/step - loss: 0.4290 - accuracy: 0.8456 - val_loss: 0.4272 - val_accuracy: 0.8442
# Epoch 35/70
# 8393/8393 [==============================] - 220s 26ms/step - loss: 0.4339 - accuracy: 0.8447 - val_loss: 0.4753 - val_accuracy: 0.8240
# Epoch 36/70
# 8393/8393 [==============================] - 220s 26ms/step - loss: 0.4347 - accuracy: 0.8445 - val_loss: 0.4481 - val_accuracy: 0.8420
# Epoch 37/70
# 8393/8393 [==============================] - 221s 26ms/step - loss: 0.4371 - accuracy: 0.8431 - val_loss: 0.6552 - val_accuracy: 0.7823
# Epoch 38/70
# 8393/8393 [==============================] - 220s 26ms/step - loss: 0.4360 - accuracy: 0.8439 - val_loss: 0.4339 - val_accuracy: 0.8384
# Epoch 39/70
# 8393/8393 [==============================] - 220s 26ms/step - loss: 0.4437 - accuracy: 0.8419 - val_loss: 2.4545 - val_accuracy: 0.4257
# Epoch 40/70
# 8393/8393 [==============================] - 223s 27ms/step - loss: 0.4386 - accuracy: 0.8432 - val_loss: 0.4833 - val_accuracy: 0.8253
# Epoch 41/70
# 8393/8393 [==============================] - 221s 26ms/step - loss: 0.4414 - accuracy: 0.8424 - val_loss: 0.4281 - val_accuracy: 0.8445
# Epoch 42/70
# 8393/8393 [==============================] - 220s 26ms/step - loss: 0.4410 - accuracy: 0.8428 - val_loss: 0.4204 - val_accuracy: 0.8513
# Epoch 43/70
# 8393/8393 [==============================] - 221s 26ms/step - loss: 0.4385 - accuracy: 0.8430 - val_loss: 0.4221 - val_accuracy: 0.8483
# Epoch 44/70
# 8393/8393 [==============================] - 220s 26ms/step - loss: 0.4331 - accuracy: 0.8445 - val_loss: 0.4431 - val_accuracy: 0.8392
# Epoch 45/70
# 8393/8393 [==============================] - 221s 26ms/step - loss: 0.4303 - accuracy: 0.8454 - val_loss: 0.4184 - val_accuracy: 0.8497
# Epoch 46/70
# 8393/8393 [==============================] - 221s 26ms/step - loss: 0.4296 - accuracy: 0.8459 - val_loss: 0.4071 - val_accuracy: 0.8497
# Epoch 47/70
# 8393/8393 [==============================] - 223s 27ms/step - loss: 0.4239 - accuracy: 0.8475 - val_loss: 0.4260 - val_accuracy: 0.8478
# Epoch 48/70
# 8393/8393 [==============================] - 220s 26ms/step - loss: 0.4204 - accuracy: 0.8480 - val_loss: 0.4013 - val_accuracy: 0.8530
# Epoch 49/70
# 8393/8393 [==============================] - 221s 26ms/step - loss: 0.4170 - accuracy: 0.8492 - val_loss: 0.3952 - val_accuracy: 0.8559
# Epoch 50/70
# 8393/8393 [==============================] - 221s 26ms/step - loss: 0.4101 - accuracy: 0.8513 - val_loss: 0.3909 - val_accuracy: 0.8577
# Epoch 51/70
# 8393/8393 [==============================] - 221s 26ms/step - loss: 0.4047 - accuracy: 0.8528 - val_loss: 0.3850 - val_accuracy: 0.8607
# Epoch 52/70
# 8393/8393 [==============================] - 221s 26ms/step - loss: 0.4034 - accuracy: 0.8533 - val_loss: 1.0473 - val_accuracy: 0.7401
# Epoch 53/70
# 8393/8393 [==============================] - 221s 26ms/step - loss: 0.3981 - accuracy: 0.8546 - val_loss: 0.3817 - val_accuracy: 0.8603
# Epoch 54/70
# 8393/8393 [==============================] - 223s 27ms/step - loss: 0.3922 - accuracy: 0.8565 - val_loss: 0.3789 - val_accuracy: 0.8613
# Epoch 55/70
# 8393/8393 [==============================] - 221s 26ms/step - loss: 0.3877 - accuracy: 0.8580 - val_loss: 0.3667 - val_accuracy: 0.8662
# Epoch 56/70
# 8393/8393 [==============================] - 221s 26ms/step - loss: 0.3819 - accuracy: 0.8594 - val_loss: 0.3991 - val_accuracy: 0.8565
# Epoch 57/70
# 8393/8393 [==============================] - 221s 26ms/step - loss: 0.3761 - accuracy: 0.8609 - val_loss: 0.3631 - val_accuracy: 0.8663
# Epoch 58/70
# 8393/8393 [==============================] - 221s 26ms/step - loss: 0.3710 - accuracy: 0.8623 - val_loss: 0.3771 - val_accuracy: 0.8612
# Epoch 59/70
# 8393/8393 [==============================] - 220s 26ms/step - loss: 0.3660 - accuracy: 0.8640 - val_loss: 0.3662 - val_accuracy: 0.8655
# Epoch 60/70
# 8393/8393 [==============================] - 221s 26ms/step - loss: 0.3612 - accuracy: 0.8650 - val_loss: 0.3533 - val_accuracy: 0.8702
# Epoch 61/70
# 8393/8393 [==============================] - 223s 27ms/step - loss: 0.3564 - accuracy: 0.8668 - val_loss: 0.3484 - val_accuracy: 0.8703
# Epoch 62/70
# 8393/8393 [==============================] - 220s 26ms/step - loss: 0.3520 - accuracy: 0.8678 - val_loss: 0.3502 - val_accuracy: 0.8705
# Epoch 63/70
# 8393/8393 [==============================] - 220s 26ms/step - loss: 0.3478 - accuracy: 0.8691 - val_loss: 0.3679 - val_accuracy: 0.8663
# Epoch 64/70
# 8393/8393 [==============================] - 221s 26ms/step - loss: 0.3442 - accuracy: 0.8701 - val_loss: 0.3425 - val_accuracy: 0.8723
# Epoch 65/70
# 8393/8393 [==============================] - 221s 26ms/step - loss: 0.3412 - accuracy: 0.8709 - val_loss: 0.3405 - val_accuracy: 0.8733
# Epoch 66/70
# 8393/8393 [==============================] - 220s 26ms/step - loss: 0.3383 - accuracy: 0.8718 - val_loss: 0.3402 - val_accuracy: 0.8739
# Epoch 67/70
# 8393/8393 [==============================] - 221s 26ms/step - loss: 0.3364 - accuracy: 0.8726 - val_loss: 0.3475 - val_accuracy: 0.8719
# Epoch 68/70
# 8393/8393 [==============================] - 223s 27ms/step - loss: 0.3349 - accuracy: 0.8730 - val_loss: 0.3380 - val_accuracy: 0.8751
# Epoch 69/70
# 8393/8393 [==============================] - 221s 26ms/step - loss: 0.3330 - accuracy: 0.8736 - val_loss: 0.3373 - val_accuracy: 0.8750
# Epoch 70/70
# 7154/8393 [========================>.....] - ETA: 30s - loss: 0.3318 - accuracy: 0.8740

# %%
smv2_l.save('./smv2l_adam_lrsch_onecycle_aug_dropout_128_he_irb6_512_epoch70.h5')
